# %% [markdown]
# # Reto de la Semanan 4: Optimización con Regresión Logística
#
# Este cuaderno implementa la solución al problema de optimización para encontrar los parámetros óptimos de un clasificador binario lineal utilizando regresión logística, basándose en el documento proporcionado y el conjunto de datos `breastCancer`.

# %%
#  Importamos las librerías necesarias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
# importamos los datos
ruta_archivo = 'BreastCancer.csv'
data = pd.read_csv(ruta_archivo)

# %%
X = data[['radius_mean', 'smoothness_mean']].values

# Extract target variable (t)
t = data['pronostic'].values

# Add a column of ones to X to create the Z matrix [x, 1]^T
Z = np.hstack((X, np.ones((X.shape[0], 1))))

m = Z.shape[0] # Number of training examples
n = Z.shape[1] # Number of features (including the intercept)

print(f"\nShape of Z (features + intercept): {Z.shape}")
print(f"Shape of t (target): {t.shape}")
# Out:
# Shape of Z (features + intercept): (469, 3)
# Shape of t (target): (469,)

# %%
def sigmoid(v):
    """
    Sigmoid function.
    """
    return 1 / (1 + np.exp(-v))

# %%
def loss_function(w, Z, t):
    """
    Logistic Regression Loss Function f(w).
    """
    y = sigmoid(Z @ w) # Z @ w is equivalent to Z.dot(w)
    epsilon = 1e-15 # Small value to prevent log(0)
    loss = -np.mean(t * np.log(y + epsilon) + (1 - t) * np.log(1 - y + epsilon))
    return loss

# %%
def gradient(w, Z, t):
    """
    Gradient of the Logistic Regression Loss Function.
    """
    y = sigmoid(Z @ w)
    grad = (1/m) * Z.T @ (y - t) # Z.T @ (y - t) is equivalent to Z.T.dot(y - t)
    return grad

# %%
def hessian(w, Z, t):
    """
    Hessian of the Logistic Regression Loss Function.
    """
    y = sigmoid(Z @ w)
    S = np.diag(y * (1 - y))
    hess = (1/m) * Z.T @ S @ Z # Z.T @ S @ Z is equivalent to Z.T.dot(S).dot(Z)
    return hess

# %%
initial_w = np.zeros(n)

# Use minimize to find the optimal w
result = minimize(loss_function, initial_w, args=(Z, t), method='CG', jac=gradient)

# Extract the optimal w
optimal_w = result.x

print(f"\nOptimization Result:")
print(f"Success: {result.success}")
print(f"Message: {result.message}")
print(f"Optimal w: {optimal_w}")
# Out:
# Optimization Result:
# Success: True
# Message: Optimization terminated successfully.
# Optimal w: [5.36052956 1.64164044 0.24463664]

# %%
# Calcular el valor de la función objetivo, el gradiente y la Hessiana en el $w$ encontrado.

# %%
loss_at_optimal_w = loss_function(optimal_w, Z, t)
gradient_at_optimal_w = gradient(optimal_w, Z, t)
hessian_at_optimal_w = hessian(optimal_w, Z, t)

print(f"\nLoss at optimal w: {loss_at_optimal_w}")
print(f"Gradient at optimal w: {gradient_at_optimal_w}")
print(f"Hessian at optimal w:\n{hessian_at_optimal_w}")
# Out:
# Loss at optimal w: 0.20464127697655204
# Gradient at optimal w: [8.30765582e-06 6.31498452e-07 1.44867554e-06]
# Hessian at optimal w:
# [[ 0.01005425 -0.01356427 -0.0103909 ]
#  [-0.01356427  0.05475941  0.00994577]
#  [-0.0103909   0.00994577  0.06328283]]

# %%
initial_w = np.zeros(n)

# Use minimize to find the optimal w
result = minimize(loss_function, initial_w, args=(Z, t), method='CG', jac=gradient)

# Extract the optimal w
optimal_w = result.x

print(f"\nOptimization Result:")
print(f"Success: {result.success}")
print(f"Message: {result.message}")
print(f"Optimal w: {optimal_w}")
# Out:
# Optimization Result:
# Success: True
# Message: Optimization terminated successfully.
# Optimal w: [5.36052956 1.64164044 0.24463664]

# %%
# ## 9. Calcular Valores en el $w$ Óptimo
#
# Calcular el valor de la función objetivo, el gradiente y la Hessiana en el $w$ encontrado.

# %%
loss_at_optimal_w = loss_function(optimal_w, Z, t)
gradient_at_optimal_w = gradient(optimal_w, Z, t)
hessian_at_optimal_w = hessian(optimal_w, Z, t)

print(f"\nLoss at optimal w: {loss_at_optimal_w}")
print(f"Gradient at optimal w: {gradient_at_optimal_w}")
print(f"Hessian at optimal w:\n{hessian_at_optimal_w}")
# Out:
# Loss at optimal w: 0.20464127697655204
# Gradient at optimal w: [8.30765582e-06 6.31498452e-07 1.44867554e-06]
# Hessian at optimal w:
# [[ 0.01005425 -0.01356427 -0.0103909 ]
#  [-0.01356427  0.05475941  0.00994577]
#  [-0.0103909   0.00994577  0.06328283]]

# %%
# Scatter plot of the data points, colored by class
plt.figure(figsize=(10, 6))
plt.scatter(X[t == 0, 0], X[t == 0, 1], color='red', label='Class 0 (Not Malignant)')
plt.scatter(X[t == 1, 0], X[t == 1, 1], color='blue', label='Class 1 (Malignant)')

# Plot the decision boundary line w1*x1 + w2*x2 + w3 = 0
# Rearrange to solve for x2: x2 = (-w1/w2)*x1 + (-w3/w2)
if optimal_w[1] != 0:
    x1_values = np.array([X[:, 0].min(), X[:, 0].max()])
    x2_values = (-optimal_w[0] / optimal_w[1]) * x1_values - (optimal_w[2] / optimal_w[1])
    plt.plot(x1_values, x2_values, color='green', linestyle='--', label='Decision Boundary')

plt.xlabel('radius_mean')
plt.ylabel('smoothness_mean')
plt.title('Logistic Regression Decision Boundary')
plt.legend()
plt.grid(True)
plt.show()
